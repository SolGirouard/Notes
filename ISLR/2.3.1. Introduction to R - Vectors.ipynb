# %%
x <- c(1,3,2,5)
x
# Out:
# [1] 1 3 2 5

# %%
x = c(1, 6, 2)
x
# Out:
# [1] 1 6 2

# %%
y = c(1,4,3)

# %%
length(x)
# Out:
# [1] 3

# %%
length(y)
# Out:
# [1] 3

# %%
# Add vectors element wise
x+y
# Out:
# [1]  2 10  5

# %%
# List all objects
ls()
# Out:
# [1] "x" "y"

# %%
# Remove any objects we don't want
rm(x, y)
ls()
# Out:
# character(0)

# %%
# remove all objects at once
rm(list=ls())

# %%
# Vector of 50 random normal variables
x=rnorm(50)

# %%
x
# Out:
#  [1]  1.060646664  0.160415958 -0.404099891  1.436173748  0.183606438
#  [6]  1.194604795 -0.002154268 -0.991956526 -0.992974580 -0.878111735
# [11] -0.739245680 -0.867934697 -1.048582008 -1.122978430  0.230660352
# [16]  1.574284369 -0.669914696  1.378007685  0.568594916 -1.001382500
# [21]  0.356157780 -1.390400186  0.920388526  0.254958911  0.262083754
# [26] -1.305009409 -1.674055257 -0.457059803  1.242371707  0.155076246
# [31] -0.908386445  2.050289902  0.814085067  0.509444219 -0.352202425
# [36] -0.257018395 -2.053767834 -0.816068550 -0.364760812 -2.552192342
# [41]  1.788141426  1.020635833 -0.216391369 -0.669372363 -0.378858400
# [46] -0.125825168 -0.454568189  0.014831815  0.638854710  0.245415528

# %%
y = x + rnorm(50, mean=50, sd = 0.1)

# %%
y
# Out:
#  [1] 50.97715 50.15824 49.55907 51.72022 50.21834 51.19769 50.08033 49.06695
#  [9] 49.07526 49.23143 49.36635 49.02827 49.03683 49.01853 50.11201 51.53280
# [17] 49.36034 51.35600 50.81639 48.81491 50.43998 48.74811 50.92309 50.20763
# [25] 50.23859 48.71967 48.30458 49.32769 51.41482 50.09181 49.16121 52.03399
# [33] 50.79114 50.52877 49.66582 49.77575 47.96243 49.36535 49.58549 47.45087
# [41] 51.86181 50.97760 49.79773 49.35240 49.60510 49.92094 49.58792 49.98426
# [49] 50.56217 50.18780

# %%
cor(x, y)
# Out:
# [1] 0.9956204

# %%
# Seed random variables
set.seed(1303)
rnorm(50)
# Out:
#  [1] -1.1439763145  1.3421293656  2.1853904757  0.5363925179  0.0631929665
#  [6]  0.5022344825 -0.0004167247  0.5658198405 -0.5725226890 -1.1102250073
# [11] -0.0486871234 -0.6956562176  0.8289174803  0.2066528551 -0.2356745091
# [16] -0.5563104914 -0.3647543571  0.8623550343 -0.6307715354  0.3136021252
# [21] -0.9314953177  0.8238676185  0.5233707021  0.7069214120  0.4202043256
# [26] -0.2690521547 -1.5103172999 -0.6902124766 -0.1434719524 -1.0135274099
# [31]  1.5732737361  0.0127465055  0.8726470499  0.4220661905 -0.0188157917
# [36]  2.6157489689 -0.6931401748 -0.2663217810 -0.7206364412  1.3677342065
# [41]  0.2640073322  0.6321868074 -1.3306509858  0.0268888182  1.0406363208
# [46]  1.3120237985 -0.0300020767 -0.2500257125  0.0234144857  1.6598706557

# %%
set.seed(3)
y=rnorm(100)

# %%
mean(y)
# Out:
# [1] 0.01103557

# %%
var(y)
# Out:
# [1] 0.7328675

# %%
sqrt(var(y))
# Out:
# [1] 0.8560768

# %%
sd(y)
# Out:
# [1] 0.8560768
